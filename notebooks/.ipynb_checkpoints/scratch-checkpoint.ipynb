# %%
# %matplotlib inline
import helpers
reload(helpers)
from helpers import *

# %%
import allantools
from scipy import signal


def fit_fig(fig, func, p_guess={}, p_fix=[], fit_range=[0, None], do_print=0, show_guess=0, fig_choice=0, color='r'):
    p_guessed = p_guess.copy()
    try:
        ax = fig.get_axes()[fig_choice]
        indi, indf = fit_range
        x, y = ax.get_lines()[-1].get_xydata()[indi:indf].T
        p_fit, p_err = fit(func, p_guess, x, y, p_fix=p_fix)
        x_fit = np.linspace(x.min(), x.max(), 1000)
        if show_guess:
            raise Exception
        ax.plot(x_fit, func(p_fit)(x_fit),color)
        
        # make fit values easier to read
        p_fit = {k: v
            for k, v in p_fit.items()}
        p_err = {k: v for k, v in p_err.items()}
        if do_print:
            print '-------- fit results --------' 
            print 'fit: ', p_fit
            print 'err: ', p_err
        return p_fit, p_err
    except RuntimeError:
        print 'bad fit'
        x_fit = np.linspace(x.min(), x.max(), 1000)
        ax.plot(x_fit, func(p_guessed)(x_fit), 'r--')
        return p_guessed, p_guessed
    except Exception as e:
        print e
        x_fit = np.linspace(x.min(), x.max(), 1000)
        ax.plot(x_fit, func(p_guessed)(x_fit), 'r--')
        return p_guessed, p_guessed

# %% [markdown]
# # find line

# %%
zero_freq = 27.866e6
center_shift = -230
zeeman_shift = 264
f0 = zero_freq - zeeman_shift - center_shift

fig = None

camera_args = {
    'name': 'andor',
    'offset': (522, 187),
    'size': (200, 200),
    'roi': {
        'all': [30, 30, 0, 0],
        'center': [10, 10, 0, 0],        
        },
    'norm': (0, 0, 60, 80),
    'pulse_length': 5,
    }

fit_settings = {
    'p': {'a': .2, 'b': 1, 'Gamma': 10, 'x0': 0},
    'p_fix': ['b'],
    'region': 'center',
    }

data_sets = {   
    '../../20171121/scan_clock#35': {
        'camera_args': camera_args,
#         'fit_settings': fit_settings,
        },
    '../../20171121/scan_clock#37': {
        'camera_args': camera_args,
#         'fit_settings': fit_settings,
        },         
    }
    
for filename, data_set in data_sets.items():
    data = Data(filename)
    data['name'] = filename
    load_images(data, data_set['camera_args'])
    process_images_eg(data, data_set['camera_args'])
    data = process_clock_scan_camera(data, f0)
    if data_set.get('fit_settings'):
        data = fit_clock_scan_camera(data, data_set.get('fit_settings'), do_print=True)
    data_set['data'] = data

# %%
fig = None

FILENAME = '../../20171121/scan_clock#37'
data = data_sets[FILENAME]['data']
fig = plot_clock_scan_camera(data, 'center', fig=fig)

FILENAME = '../../20171121/scan_clock#35'
data = data_sets[FILENAME]['data']
fig = plot_clock_scan_camera(data, 'center', fig=fig)

# %%
for e, g, frac, tot, ig, ie in zip(data['andor']['n_e'], data['andor']['n_g'], 
                      data['andor']['frac'], data['andor']['tot'],
                      data['andor']['image_g'], data['andor']['image_e'])[-5:]:
    plot_camera_image(tot, camera_args, cmap='magma')
    plot_camera_image(frac, camera_args, cmap='PuOr', vmin=0, vmax=1)
    plot_camera_image(ie, camera_args, cmap='magma')

# %% [markdown]
# ## lock clock

# %%
zero_freq = 27.866e6
center_shift = -230
zeeman_shift = 264
f0 = zero_freq - center_shift

filename = '../../20171121/clock_lock#50'
data = Data(filename)
# print data['clock_servo']['dither_lock']

fig, ax = plt.subplots(1)

ax.plot(f0 - data['+9/2']['frequency'][4:])
ax.plot(f0 - data['-9/2']['frequency'][4:] + 2 * zeeman_shift, 'r')

fig, ax = plt.subplots(2, 1, sharex=True)
# ax.plot(data['andor']['frac'][1:])

for i, (frac, tot, lock) in enumerate(zip(
        data['andor']['frac'][2:], 
        data['andor']['tot'][2:], 
        data['clock_servo']['dither_lock'][:-2]
        )):
    if lock['dither'][0] == '+9/2':
        ax[0].plot(i, frac, 'bo')
        ax[1].plot(i, tot, 'bo')
        
    else:
        ax[0].plot(i, frac, 'ro')
        ax[1].plot(i, tot, 'ro')
        
# fig, ax = plt.subplots(1)
# ax.plot(data['+9/2']['frequency'][:-2] - data['-9/2']['frequency'][2:])

fig, ax = plt.subplots(1)
ax.plot(f0 - (data['+9/2']['frequency'][4:] + data['-9/2']['frequency'][4:]) / 2.)

# freqs = f0 - (data['+9/2']['frequency'][:-2] + data['-9/2']['frequency'][2:]) / 2.

# freqs = signal.detrend(data['-9/2']['frequency'][20:])
# freqs = signal.detrend(data['-9/2']['frequency'][20:200])
# (taus, devs, errs, n) = allantools.adev(freqs/429e12, rate=1. / (4 * 14.58), data_type='freq')

# fig, ax = plt.subplots(1)
# for tau, dev, err in zip(taus, devs, errs):
#     ax.plot(tau, dev, 'ko')
#     ax.plot([tau, tau], [dev - err, dev + err], 'k-')
# ax.set_yscale('log')
# ax.set_xscale('log')

# %%
import data_tools.process_clock_lock
reload(data_tools.process_clock_lock)
from data_tools.process_clock_lock import *

# %%
zero_freq = 27.866e6
center_shift = -230
zeeman_shift = 264
f0 = zero_freq - center_shift

filename = '../../20171121/clock_lock#51'

fig = plot_clock_lock(filename, f0, allan_cuts=[(20, None)])
